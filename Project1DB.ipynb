# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st 
import numpy as np
possible_chart_1_path= "songs_normalize.csv"
possible_chart_1_df= pd.read_csv(possible_chart_1_path)
possible_chart_1_df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
#tempo vs popularity bar graph 
dataFrame.plot.bar(x="tempo", y="popularity", rot=70, title="Tempo vs Popularity");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18676\469350698.py in <module>
#       1 #tempo vs popularity bar graph
# ----> 2 dataFrame.plot.bar(x="tempo", y="popularity", rot=70, title="Tempo vs Popularity");
#
# NameError: name 'dataFrame' is not defined

# %%
plt.bar(major_songs["tempo"], major_songs["danceability"], c="blue")
plt.bar(minor_songs["tempo"], minor_songs["danceability"], c="violet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18676\2319006262.py in <module>
# ----> 1 plt.bar(major_songs["tempo"], major_songs["danceability"], c="blue")
#       2 plt.bar(minor_songs["tempo"], minor_songs["danceability"], c="violet")
#
# NameError: name 'major_songs' is not defined

# %%
artist_count=possible_chart_1_df.duplicated(["artist"])
artist_count
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995     True
# 1996     True
# 1997    False
# 1998     True
# 1999     True
# Length: 2000, dtype: bool

# %%
possible_chart_1_df.max()
# Out:
# artist                    will.i.am
# song                Échame La Culpa
# duration_ms                  484146
# explicit                       True
# year                           2020
# popularity                       89
# danceability                  0.975
# energy                        0.999
# key                              11
# loudness                     -0.276
# mode                              1
# speechiness                   0.576
# acousticness                  0.976
# instrumentalness              0.985
# liveness                      0.853
# valence                       0.973
# tempo                       210.851
# genre                         set()
# dtype: object

# %%
possible_chart_1_df.mode()
# Out:
#     artist   song  duration_ms explicit    year  popularity  danceability  \
# 0  Rihanna  Sorry     212106.0    False  2012.0         0.0         0.688
# 1      NaN    NaN          NaN      NaN     NaN         NaN         0.736
# 2      NaN    NaN          NaN      NaN     NaN         NaN           NaN
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.783  1.0    -6.366   1.0       0.0432         0.107               0.0
# 1     NaN  NaN       NaN   NaN          NaN         0.150               NaN
# 2     NaN  NaN       NaN   NaN          NaN         0.230               NaN
#
#    liveness  valence    tempo genre
# 0     0.104    0.418  140.022   pop
# 1       NaN      NaN      NaN   NaN
# 2       NaN      NaN      NaN   NaN

# %%
possible_chart_1_df.nunique()
# Out:
# artist               835
# song                1879
# duration_ms         1793
# explicit               2
# year                  23
# popularity            76
# danceability         565
# energy               580
# key                   12
# loudness            1671
# mode                   2
# speechiness          837
# acousticness        1208
# instrumentalness     772
# liveness             783
# valence              760
# tempo               1831
# genre                 59
# dtype: int64

# %%
x_axis = possible_chart_1_df["tempo"]
y_axis = possible_chart_1_df["popularity"]

plt.bar(x_axis,y_axis, color= "r", alpha=1)
plt.title("Popularity vs tempo")
plt.xticks(rotation='vertical')
# Out:
# (array([ 40.,  60.,  80., 100., 120., 140., 160., 180., 200., 220.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
print(y_axis)
# Out:
# 0       77
# 1       79
# 2       66
# 3       78
# 4       65
#         ..
# 1995    79
# 1996    78
# 1997    69
# 1998    75
# 1999    85
# Name: popularity, Length: 2000, dtype: int64

# %%
# plot the data points as bar graphs with two different colors
x_axis=possible_chart_1_df["tempo"]
y_axis=possible_chart_1_df["popularity"]
plt.bar(x_axis, y_axis, color="blue", width=0.2)
plt.bar(x_axis,y_axis, color="violet", width=0.2)
# set x and y labels
plt.xlabel("Tempo")
plt.ylabel("Popularity")
# Bar graph dimensions
bar_width = 10.00
bar_height = 7.0
# show the plot
plt.show()
